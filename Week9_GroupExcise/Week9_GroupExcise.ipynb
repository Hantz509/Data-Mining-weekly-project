# %% [markdown]
# ### Week 9 Group Homework: Association Rules
#
# For this week, use the given dataset to perform association rule mining with **Apriori-based approaches** using **mlxtend** and **apyori**.

# %%
dataset = [
    ["Bread", "Milk"],
    ["Bread", "Diaper", "Beer", "Eggs"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"],
    ["Bread", "Milk", "Cheese"],
    ["Milk", "Yogurt", "Butter"],
    ["Bread", "Pasta", "Rice"],
    ["Milk", "Juice", "Chips"],
    ["Diaper", "Beer", "Soda"],
    ["Bread", "Milk", "Chocolate"],
    ["Milk", "Diaper", "Beer", "Cola"],
    ["Bread", "Milk", "Diaper", "Beer"],
    ["Bread", "Milk", "Diaper", "Cola"],
    ["Diaper", "Beer"],
    ["Bread", "Milk", "Beer"],
    ["Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Beer", "Eggs"],
    ["Bread", "Milk", "Diaper", "Cola", "Eggs"]
]
